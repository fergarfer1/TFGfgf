# %%
import os
import shutil
import zipfile
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.preprocessing import image
from random import sample
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Cuenta el número de imágenes que hay por cada categoría

imag_1_hoja = 0
imag_2_hojas = 0
dir1 = "C:/Users/ferga/Documents/Python/hojas/1_mod"
dir2 = "C:/Users/ferga/Documents/Python/hojas/2_mod"
for path in os.listdir(dir1):
    if os.path.isfile(os.path.join(dir1, path)):
        imag_1_hoja += 1
for path in os.listdir(dir2):
    if os.path.isfile(os.path.join(dir2, path)):
        imag_2_hojas += 1
print('Imagenes de 1 hoja: '+ str(imag_1_hoja))
print('Imagenes de 2 hojas: '+ str(imag_2_hojas))
print('Total: ', imag_1_hoja+imag_2_hojas)
# Out:
# Imagenes de 1 hoja: 473
# Imagenes de 2 hojas: 466
# Total:  939

# %%
#Cuenta cuantas imágenes servirán para train, para validation y para test, en este caso se ha seguido el criterio 80%-10%-10% respectivamente.

n_imag_train_1 = round(imag_1_hoja*0.8)
n_imag_validation_1 = imag_1_hoja//10
n_imag_test_1 = imag_1_hoja-n_imag_train_1-n_imag_validation_1
print('1 hoja: Train=' + str(n_imag_train_1) + ' Validation=' + str(n_imag_validation_1) + ' Test=' + str(n_imag_test_1))
n_imag_train_2 = round(imag_2_hojas*0.8)
n_imag_validation_2 = imag_2_hojas//10
n_imag_test_2 = imag_2_hojas-n_imag_train_2-n_imag_validation_2
print('2 hojas: Train=' + str(n_imag_train_2) + ' Validation=' + str(n_imag_validation_2) + ' Test=' + str(n_imag_test_2))
# Out:
# 1 hoja: Train=378 Validation=47 Test=48
# 2 hojas: Train=373 Validation=46 Test=47

# %%
#Asignamos cada ruta a variables que luego serán necesarias.

base_dir = "C:/Users/ferga/Documents/Python/hojas"

train_dir =      os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir =       os.path.join(base_dir, 'test')

## Directorio con las imagenes de train
# 1 hoja.
train_weed1_dir = os.path.join(train_dir, '1')
# 2 hojas.
train_weed2_dir = os.path.join(train_dir, '2')

## Directorio con las imagenes de validation
# 1 hoja
validation_weed1_dir = os.path.join(validation_dir, '1')
# 2 hojas
validation_weed2_dir = os.path.join(validation_dir, '2')


## Directorio con las imagenes de test
# 1 hoja
test_weed1_dir = os.path.join(test_dir,'1')
# 2 hojas
test_weed2_dir = os.path.join(test_dir,'2')

# %%
# Ordena las imágenes de cada categoría en el directorio de train, validation y test.

# 1 hoja
contenido_1 = os.listdir(dir1)
contenido_1_random = sample(contenido_1, len(contenido_1))
for i in range(len(contenido_1_random)):
    if i < n_imag_train_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), train_weed1_dir)
    elif i >= n_imag_train_1 and i < n_imag_train_1+n_imag_validation_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), validation_weed1_dir)
    else:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), test_weed1_dir)
# 2 hojas
contenido_2 = os.listdir(dir2)
contenido_2_random = sample(contenido_2, len(contenido_2))
for i in range(len(contenido_2_random)):
    if i < n_imag_train_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), train_weed2_dir)
    elif i >= n_imag_train_2 and i < n_imag_train_2+n_imag_validation_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), validation_weed2_dir)
    else:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), test_weed2_dir)

# %%
# Pequeña comprobación de que las fotos están bien ordenadas

#Train
train_weed1_fnames = os.listdir( train_weed1_dir )
print(train_weed1_fnames[:5])
train_weed2_fnames = os.listdir( train_weed2_dir )
print(train_weed2_fnames[:5])

#Validation

#Test
# Out:
# ['0.png', '10.png', '106.png', '107.png', '110.png']
# ['1.png', '10.png', '102.png', '103.png', '105.png']

# %%
#Comprueba el numero de fotos que hay en cada directorio para verificar que se ha realizado el reparto correctamente

print('total training weed1 images :', len(os.listdir(train_weed1_dir ) ))
print('total training weed2 images :', len(os.listdir(train_weed2_dir ) ))

print('total validation weed1 images :', len(os.listdir( validation_weed1_dir ) ))
print('total validation weed2 images :', len(os.listdir( validation_weed2_dir ) ))

print('total test weed1 images :', len(os.listdir( test_weed1_dir ) ))
print('total test weed2 images :', len(os.listdir( test_weed2_dir ) ))
# Out:
# total training weed1 images : 378
# total training weed2 images : 373
# total validation weed1 images : 47
# total validation weed2 images : 46
# total test weed1 images : 48
# total test weed2 images : 47

# %%
# Representa un ejemplo de las imágenes que se van a tomar para resolver el problema. En este caso se representarán las de dos hojas

# presentaremos images en una configuración de 4x4
nrows = 4
ncols = 4

pic_index = 0 # Índice para iterar sobre las imagenes

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_weed_pix = [os.path.join(train_weed1_dir, fname) 
                for fname in train_weed1_fnames[ pic_index-8:pic_index] 
               ]

for i, img_path in enumerate(next_weed_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  img = mpimg.imread(img_path)
  plt.imshow(img)
  
plt.show()

# %%
#Creación de la CNN

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu', ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 1,241,410
# Trainable params: 1,241,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
      rescale=1.0/255.,
      rotation_range=60,
      horizontal_flip=True,
      vertical_flip=True,
      fill_mode='nearest'
      )
validation_datagen  = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator =  validation_datagen.flow_from_directory(validation_dir,
                                                         batch_size=20,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))


test_generator =  test_datagen.flow_from_directory(test_dir,
                                                         batch_size=20,
                                                         shuffle=False,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))
# Out:
# Found 751 images belonging to 2 classes.
# Found 93 images belonging to 2 classes.
# Found 95 images belonging to 2 classes.

# %%
batch_size = 20
steps_per_epoch = train_generator.n // batch_size
validation_steps = validation_generator.n // batch_size

print (steps_per_epoch)
print (validation_steps)
# Out:
# 37
# 4

# %%
history = model.fit(
    train_generator, 
    steps_per_epoch= steps_per_epoch,
    epochs=100,
    validation_data=validation_generator,
    validation_steps= validation_steps,
    verbose=1)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 42s 565ms/step - loss: 0.6861 - accuracy: 0.5378 - val_loss: 0.6816 - val_accuracy: 0.6000
# Epoch 2/100
# 37/37 [==============================] - 8s 209ms/step - loss: 0.6693 - accuracy: 0.6216 - val_loss: 0.6678 - val_accuracy: 0.6875
# Epoch 3/100
# 37/37 [==============================] - 8s 228ms/step - loss: 0.6436 - accuracy: 0.6895 - val_loss: 0.6351 - val_accuracy: 0.7125
# Epoch 4/100
# 37/37 [==============================] - 8s 214ms/step - loss: 0.6017 - accuracy: 0.7237 - val_loss: 0.5861 - val_accuracy: 0.7375
# Epoch 5/100
# 37/37 [==============================] - 7s 189ms/step - loss: 0.5683 - accuracy: 0.7059 - val_loss: 0.5500 - val_accuracy: 0.7125
# Epoch 6/100
# 37/37 [==============================] - 7s 184ms/step - loss: 0.5289 - accuracy: 0.7305 - val_loss: 0.5121 - val_accuracy: 0.7250
# Epoch 7/100
# 37/37 [==============================] - 7s 195ms/step - loss: 0.5102 - accuracy: 0.7497 - val_loss: 0.4997 - val_accuracy: 0.7125
# Epoch 8/100
# 37/37 [==============================] - 8s 225ms/step - loss: 0.4945 - accuracy: 0.7729 - val_loss: 0.4423 - val_accuracy: 0.7375
# Epoch 9/100
# 37/37 [==============================] - 10s 269ms/step - loss: 0.4674 - accuracy: 0.7893 - val_loss: 0.4436 - val_accuracy: 0.8250
# Epoch 10/100
# 37/37 [==============================] - 8s 203ms/step - loss: 0.4712 - accuracy: 0.7811 - val_loss: 0.4216 - val_accuracy: 0.7875
# Epoch 11/100
# 37/37 [==============================] - 8s 204ms/step - loss: 0.4743 - accuracy: 0.7839 - val_loss: 0.4108 - val_accuracy: 0.8375
# Epoch 12/100
# 37/37 [==============================] - 7s 181ms/step - loss: 0.4419 - accuracy: 0.7975 - val_loss: 0.3833 - val_accuracy: 0.8250
# Epoch 13/100
# 37/37 [==============================] - 7s 182ms/step - loss: 0.4503 - accuracy: 0.8016 - val_loss: 0.4149 - val_accuracy: 0.8125
# Epoch 14/100
# 37/37 [==============================] - 7s 193ms/step - loss: 0.4242 - accuracy: 0.8181 - val_loss: 0.3801 - val_accuracy: 0.8625
# Epoch 15/100
# 37/37 [==============================] - 7s 179ms/step - loss: 0.4137 - accuracy: 0.8222 - val_loss: 0.3859 - val_accuracy: 0.8625
# Epoch 16/100
# 37/37 [==============================] - 7s 177ms/step - loss: 0.4169 - accuracy: 0.8098 - val_loss: 0.3952 - val_accuracy: 0.8625
# Epoch 17/100
# 37/37 [==============================] - 8s 216ms/step - loss: 0.4019 - accuracy: 0.8194 - val_loss: 0.3679 - val_accuracy: 0.8750
# Epoch 18/100
# 37/37 [==============================] - 7s 185ms/step - loss: 0.4034 - accuracy: 0.8324 - val_loss: 0.3679 - val_accuracy: 0.8250
# Epoch 19/100
# 37/37 [==============================] - 8s 209ms/step - loss: 0.3936 - accuracy: 0.8263 - val_loss: 0.3560 - val_accuracy: 0.8750
# Epoch 20/100
# 37/37 [==============================] - 7s 199ms/step - loss: 0.3890 - accuracy: 0.8468 - val_loss: 0.3130 - val_accuracy: 0.8875
# Epoch 21/100
# 37/37 [==============================] - 7s 196ms/step - loss: 0.3752 - accuracy: 0.8440 - val_loss: 0.3761 - val_accuracy: 0.8375
# Epoch 22/100
# 37/37 [==============================] - 7s 190ms/step - loss: 0.3612 - accuracy: 0.8440 - val_loss: 0.4235 - val_accuracy: 0.8125
# Epoch 23/100
# 37/37 [==============================] - 8s 213ms/step - loss: 0.3667 - accuracy: 0.8509 - val_loss: 0.3102 - val_accuracy: 0.8500
# Epoch 24/100
# 37/37 [==============================] - 7s 187ms/step - loss: 0.3625 - accuracy: 0.8550 - val_loss: 0.2750 - val_accuracy: 0.8750
# Epoch 25/100
# 37/37 [==============================] - 7s 191ms/step - loss: 0.3335 - accuracy: 0.8755 - val_loss: 0.3286 - val_accuracy: 0.8750
# Epoch 26/100
# 37/37 [==============================] - 7s 184ms/step - loss: 0.3421 - accuracy: 0.8646 - val_loss: 0.3101 - val_accuracy: 0.9125
# Epoch 27/100
# 37/37 [==============================] - 7s 194ms/step - loss: 0.3472 - accuracy: 0.8659 - val_loss: 0.2631 - val_accuracy: 0.9125
# Epoch 28/100
# 37/37 [==============================] - 7s 185ms/step - loss: 0.3196 - accuracy: 0.8687 - val_loss: 0.2822 - val_accuracy: 0.9125
# Epoch 29/100
# 37/37 [==============================] - 7s 184ms/step - loss: 0.2835 - accuracy: 0.8851 - val_loss: 0.2673 - val_accuracy: 0.8625
# Epoch 30/100
# 37/37 [==============================] - 7s 180ms/step - loss: 0.3171 - accuracy: 0.8796 - val_loss: 0.2557 - val_accuracy: 0.9125
# Epoch 31/100
# 37/37 [==============================] - 7s 195ms/step - loss: 0.2620 - accuracy: 0.8988 - val_loss: 0.2356 - val_accuracy: 0.9125
# Epoch 32/100
# 37/37 [==============================] - 7s 177ms/step - loss: 0.2726 - accuracy: 0.8919 - val_loss: 0.2720 - val_accuracy: 0.8875
# Epoch 33/100
# 37/37 [==============================] - 9s 253ms/step - loss: 0.2431 - accuracy: 0.9111 - val_loss: 0.2331 - val_accuracy: 0.9125
# Epoch 34/100
# 37/37 [==============================] - 10s 279ms/step - loss: 0.3054 - accuracy: 0.8782 - val_loss: 0.2863 - val_accuracy: 0.8750
# Epoch 35/100
# 37/37 [==============================] - 11s 291ms/step - loss: 0.2450 - accuracy: 0.9162 - val_loss: 0.2808 - val_accuracy: 0.8875
# Epoch 36/100
# 37/37 [==============================] - 11s 291ms/step - loss: 0.2314 - accuracy: 0.9029 - val_loss: 0.1949 - val_accuracy: 0.9375
# Epoch 37/100
# 37/37 [==============================] - 9s 226ms/step - loss: 0.2670 - accuracy: 0.8919 - val_loss: 0.2647 - val_accuracy: 0.8750
# Epoch 38/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.2159 - accuracy: 0.9124 - val_loss: 0.1923 - val_accuracy: 0.9000
# Epoch 39/100
# 37/37 [==============================] - 10s 269ms/step - loss: 0.2360 - accuracy: 0.9083 - val_loss: 0.2660 - val_accuracy: 0.8875
# Epoch 40/100
# 37/37 [==============================] - 11s 304ms/step - loss: 0.2194 - accuracy: 0.9138 - val_loss: 0.2881 - val_accuracy: 0.8625
# Epoch 41/100
# 37/37 [==============================] - 10s 281ms/step - loss: 0.2468 - accuracy: 0.9054 - val_loss: 0.2317 - val_accuracy: 0.9000
# Epoch 42/100
# 37/37 [==============================] - 10s 271ms/step - loss: 0.2113 - accuracy: 0.9261 - val_loss: 0.2179 - val_accuracy: 0.9125
# Epoch 43/100
# 37/37 [==============================] - 10s 264ms/step - loss: 0.2095 - accuracy: 0.9179 - val_loss: 0.2006 - val_accuracy: 0.9125
# Epoch 44/100
# 37/37 [==============================] - 10s 274ms/step - loss: 0.2057 - accuracy: 0.9234 - val_loss: 0.1729 - val_accuracy: 0.9500
# Epoch 45/100
# 37/37 [==============================] - 10s 276ms/step - loss: 0.1902 - accuracy: 0.9330 - val_loss: 0.1741 - val_accuracy: 0.9250
# Epoch 46/100
# 37/37 [==============================] - 10s 270ms/step - loss: 0.2178 - accuracy: 0.9289 - val_loss: 0.1447 - val_accuracy: 0.9500
# Epoch 47/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.1841 - accuracy: 0.9248 - val_loss: 0.2244 - val_accuracy: 0.8750
# Epoch 48/100
# 37/37 [==============================] - 10s 271ms/step - loss: 0.2295 - accuracy: 0.9124 - val_loss: 0.2149 - val_accuracy: 0.9125
# Epoch 49/100
# 37/37 [==============================] - 10s 271ms/step - loss: 0.1881 - accuracy: 0.9302 - val_loss: 0.1935 - val_accuracy: 0.9250
# Epoch 50/100
# 37/37 [==============================] - 11s 304ms/step - loss: 0.1826 - accuracy: 0.9316 - val_loss: 0.1557 - val_accuracy: 0.9375
# Epoch 51/100
# 37/37 [==============================] - 11s 309ms/step - loss: 0.1889 - accuracy: 0.9207 - val_loss: 0.2285 - val_accuracy: 0.9125
# Epoch 52/100
# 37/37 [==============================] - 10s 269ms/step - loss: 0.1863 - accuracy: 0.9261 - val_loss: 0.4522 - val_accuracy: 0.8250
# Epoch 53/100
# 37/37 [==============================] - 10s 276ms/step - loss: 0.1959 - accuracy: 0.9275 - val_loss: 0.2388 - val_accuracy: 0.9000
# Epoch 54/100
# 37/37 [==============================] - 8s 212ms/step - loss: 0.1803 - accuracy: 0.9357 - val_loss: 0.1523 - val_accuracy: 0.9750
# Epoch 55/100
# 37/37 [==============================] - 8s 226ms/step - loss: 0.1830 - accuracy: 0.9207 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 56/100
# 37/37 [==============================] - 8s 204ms/step - loss: 0.2103 - accuracy: 0.9166 - val_loss: 0.1919 - val_accuracy: 0.9000
# Epoch 57/100
# 37/37 [==============================] - 8s 212ms/step - loss: 0.1587 - accuracy: 0.9357 - val_loss: 0.2021 - val_accuracy: 0.9125
# Epoch 58/100
# 37/37 [==============================] - 8s 205ms/step - loss: 0.1555 - accuracy: 0.9425 - val_loss: 0.1738 - val_accuracy: 0.9375
# Epoch 59/100
# 37/37 [==============================] - 8s 210ms/step - loss: 0.1599 - accuracy: 0.9412 - val_loss: 0.1404 - val_accuracy: 0.9375
# Epoch 60/100
# 37/37 [==============================] - 7s 175ms/step - loss: 0.1637 - accuracy: 0.9248 - val_loss: 0.2152 - val_accuracy: 0.9250
# Epoch 61/100
# 37/37 [==============================] - 7s 192ms/step - loss: 0.1816 - accuracy: 0.9261 - val_loss: 0.1745 - val_accuracy: 0.9375
# Epoch 62/100
# 37/37 [==============================] - 7s 191ms/step - loss: 0.1536 - accuracy: 0.9384 - val_loss: 0.2140 - val_accuracy: 0.8875
# Epoch 63/100
# 37/37 [==============================] - 7s 192ms/step - loss: 0.1557 - accuracy: 0.9412 - val_loss: 0.1878 - val_accuracy: 0.9125
# Epoch 64/100
# 37/37 [==============================] - 7s 196ms/step - loss: 0.1425 - accuracy: 0.9384 - val_loss: 0.2473 - val_accuracy: 0.9000
# Epoch 65/100
# 37/37 [==============================] - 10s 258ms/step - loss: 0.1870 - accuracy: 0.9330 - val_loss: 0.1501 - val_accuracy: 0.9500
# Epoch 66/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.1402 - accuracy: 0.9480 - val_loss: 0.1864 - val_accuracy: 0.9250
# Epoch 67/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.94 - 9s 237ms/step - loss: 0.1467 - accuracy: 0.9480 - val_loss: 0.1985 - val_accuracy: 0.9250
# Epoch 68/100
# 37/37 [==============================] - 7s 175ms/step - loss: 0.1564 - accuracy: 0.9316 - val_loss: 0.1764 - val_accuracy: 0.9125
# Epoch 69/100
# 37/37 [==============================] - 7s 191ms/step - loss: 0.1252 - accuracy: 0.9631 - val_loss: 0.1287 - val_accuracy: 0.9500
# Epoch 70/100
# 37/37 [==============================] - 10s 266ms/step - loss: 0.1500 - accuracy: 0.9480 - val_loss: 0.1554 - val_accuracy: 0.9375
# Epoch 71/100
# 37/37 [==============================] - 10s 268ms/step - loss: 0.1677 - accuracy: 0.9330 - val_loss: 0.1370 - val_accuracy: 0.9375
# Epoch 72/100
# 37/37 [==============================] - 10s 263ms/step - loss: 0.1592 - accuracy: 0.9480 - val_loss: 0.2036 - val_accuracy: 0.9125
# Epoch 73/100
# 37/37 [==============================] - 11s 281ms/step - loss: 0.1469 - accuracy: 0.9466 - val_loss: 0.1406 - val_accuracy: 0.9375
# Epoch 74/100
# 37/37 [==============================] - 10s 271ms/step - loss: 0.1596 - accuracy: 0.9466 - val_loss: 0.1464 - val_accuracy: 0.9625
# Epoch 75/100
# 37/37 [==============================] - 10s 267ms/step - loss: 0.1548 - accuracy: 0.9466 - val_loss: 0.1528 - val_accuracy: 0.9250
# Epoch 76/100
# 37/37 [==============================] - 10s 276ms/step - loss: 0.1395 - accuracy: 0.9535 - val_loss: 0.1947 - val_accuracy: 0.9000
# Epoch 77/100
# 37/37 [==============================] - 10s 269ms/step - loss: 0.1386 - accuracy: 0.9453 - val_loss: 0.1337 - val_accuracy: 0.9500
# Epoch 78/100
# 37/37 [==============================] - 10s 270ms/step - loss: 0.1523 - accuracy: 0.9508 - val_loss: 0.1299 - val_accuracy: 0.9500
# Epoch 79/100
# 37/37 [==============================] - 10s 276ms/step - loss: 0.1331 - accuracy: 0.9480 - val_loss: 0.1061 - val_accuracy: 0.9500
# Epoch 80/100
# 37/37 [==============================] - 10s 267ms/step - loss: 0.1450 - accuracy: 0.9508 - val_loss: 0.2821 - val_accuracy: 0.8500
# Epoch 81/100
# 37/37 [==============================] - 10s 275ms/step - loss: 0.1643 - accuracy: 0.9412 - val_loss: 0.1377 - val_accuracy: 0.9375
# Epoch 82/100
# 37/37 [==============================] - 11s 285ms/step - loss: 0.1377 - accuracy: 0.9453 - val_loss: 0.1203 - val_accuracy: 0.9625
# Epoch 83/100
# 37/37 [==============================] - 10s 270ms/step - loss: 0.1157 - accuracy: 0.9549 - val_loss: 0.1530 - val_accuracy: 0.9125
# Epoch 84/100
# 37/37 [==============================] - 11s 291ms/step - loss: 0.1343 - accuracy: 0.9535 - val_loss: 0.1639 - val_accuracy: 0.9500
# Epoch 85/100
# 37/37 [==============================] - 11s 284ms/step - loss: 0.1460 - accuracy: 0.9508 - val_loss: 0.1239 - val_accuracy: 0.9625
# Epoch 86/100
# 37/37 [==============================] - 7s 177ms/step - loss: 0.1577 - accuracy: 0.9398 - val_loss: 0.1547 - val_accuracy: 0.9250
# Epoch 87/100
# 37/37 [==============================] - 7s 191ms/step - loss: 0.1325 - accuracy: 0.9466 - val_loss: 0.2019 - val_accuracy: 0.9125
# Epoch 88/100
# 37/37 [==============================] - 8s 218ms/step - loss: 0.1341 - accuracy: 0.9466 - val_loss: 0.1747 - val_accuracy: 0.9250
# Epoch 89/100
# 37/37 [==============================] - 8s 213ms/step - loss: 0.1514 - accuracy: 0.9494 - val_loss: 0.1533 - val_accuracy: 0.9250
# Epoch 90/100
# 37/37 [==============================] - 8s 220ms/step - loss: 0.1318 - accuracy: 0.9576 - val_loss: 0.1407 - val_accuracy: 0.9500
# Epoch 91/100
# 37/37 [==============================] - 8s 208ms/step - loss: 0.1266 - accuracy: 0.9576 - val_loss: 0.1360 - val_accuracy: 0.9500
# Epoch 92/100
# 37/37 [==============================] - 7s 197ms/step - loss: 0.1534 - accuracy: 0.9439 - val_loss: 0.1207 - val_accuracy: 0.9375
# Epoch 93/100
# 37/37 [==============================] - 6s 170ms/step - loss: 0.1108 - accuracy: 0.9617 - val_loss: 0.1608 - val_accuracy: 0.9000
# Epoch 94/100
# 37/37 [==============================] - 7s 194ms/step - loss: 0.1365 - accuracy: 0.9549 - val_loss: 0.2047 - val_accuracy: 0.9000
# Epoch 95/100
# 37/37 [==============================] - 7s 196ms/step - loss: 0.1313 - accuracy: 0.9466 - val_loss: 0.1702 - val_accuracy: 0.9250
# Epoch 96/100
# 37/37 [==============================] - 7s 187ms/step - loss: 0.1129 - accuracy: 0.9521 - val_loss: 0.1896 - val_accuracy: 0.9125
# Epoch 97/100
# 37/37 [==============================] - 7s 177ms/step - loss: 0.1211 - accuracy: 0.9508 - val_loss: 0.1335 - val_accuracy: 0.9625
# Epoch 98/100
# 37/37 [==============================] - 6s 168ms/step - loss: 0.1121 - accuracy: 0.9631 - val_loss: 0.1673 - val_accuracy: 0.9250
# Epoch 99/100
# 37/37 [==============================] - 7s 175ms/step - loss: 0.1408 - accuracy: 0.9521 - val_loss: 0.1704 - val_accuracy: 0.9250
# Epoch 100/100
# 37/37 [==============================] - 7s 178ms/step - loss: 0.1214 - accuracy: 0.9672 - val_loss: 0.1205 - val_accuracy: 0.9625

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs    = range(1,len(acc)+1,1) # obtener número de epochs del eje X

plt.plot  ( epochs,     acc, 'r--', label='Training acc'  )
plt.plot  ( epochs, val_acc,  'b', label='Validation acc')
plt.title ('Training and Validation Accuracy')
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()


plt.plot  ( epochs,     loss, 'r--' )
plt.plot  ( epochs, val_loss ,  'b' )
plt.title ('Training and Validation Loss'   )
plt.ylabel('loss')
plt.xlabel('epochs')

plt.legend()
plt.figure()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
test_lost, test_acc= model.evaluate(test_generator)
print ("Test Accuracy:", test_acc)
# Out:
# 5/5 [==============================] - 1s 246ms/step - loss: 0.1441 - accuracy: 0.9263
# Test Accuracy: 0.9263157844543457

# %%
# Guardar el modelo
model.save('CH_V_2hojas_cv.h5')

# %%
# Cargar modelo
model = tf.keras.models.load_model('CH_V_2hojas.h5')

# %%
# predicting images

path='hojas/test/1/829.png'
img=image.load_img(path, target_size=(150, 150))
  
x=image.img_to_array(img)
x=np.expand_dims(x, axis=0)
images = np.vstack([x])
  
classes = model.predict(images, batch_size=10)
  
print(classes[0])
  
plt.imshow(img)  
plt.show()

if classes[0,0] == 1:
    print("1 hoja")
if classes[0,1] == 1:
    print("2 hojas")

# %%
# confusion matrix
Y_pred = model.predict(test_generator, len(test_dir) // (20+1))
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))
print('Classification Report')
target_names = ['1', '2']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[45  3]
#  [ 4 43]]
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.92      0.94      0.93        48
#            2       0.93      0.91      0.92        47
#
#     accuracy                           0.93        95
#    macro avg       0.93      0.93      0.93        95
# weighted avg       0.93      0.93      0.93        95
