# %%
import os
import shutil
import zipfile
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.preprocessing import image
from random import sample
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Cuenta el número de imágenes que hay por cada categoría

imag_1_hoja = 0
imag_2_hojas = 0
imag_3_hojas = 0
imag_4_hojas = 0
imag_5_hojas = 0
imag_6_hojas = 0
imag_7_hojas = 0
dir1 = "C:/Users/ferga/Documents/Python/hojas/1_mod"
dir2 = "C:/Users/ferga/Documents/Python/hojas/2_mod"
dir3 = "C:/Users/ferga/Documents/Python/hojas/3_mod"
dir4 = "C:/Users/ferga/Documents/Python/hojas/4_mod"
dir5 = "C:/Users/ferga/Documents/Python/hojas/5_mod"
dir6 = "C:/Users/ferga/Documents/Python/hojas/6_mod"
dir7 = "C:/Users/ferga/Documents/Python/hojas/7_mod"
for path in os.listdir(dir1):
    if os.path.isfile(os.path.join(dir1, path)):
        imag_1_hoja += 1
for path in os.listdir(dir2):
    if os.path.isfile(os.path.join(dir2, path)):
        imag_2_hojas += 1
for path in os.listdir(dir3):
    if os.path.isfile(os.path.join(dir3, path)):
        imag_3_hojas += 1
for path in os.listdir(dir4):
    if os.path.isfile(os.path.join(dir4, path)):
        imag_4_hojas += 1
for path in os.listdir(dir5):
    if os.path.isfile(os.path.join(dir5, path)):
        imag_5_hojas += 1
for path in os.listdir(dir6):
    if os.path.isfile(os.path.join(dir6, path)):
        imag_6_hojas += 1
for path in os.listdir(dir7):
    if os.path.isfile(os.path.join(dir7, path)):
        imag_7_hojas += 1
print('Imagenes de 1 hoja: '+ str(imag_1_hoja))
print('Imagenes de 2 hojas: '+ str(imag_2_hojas))
print('Imagenes de 3 hojas: '+ str(imag_3_hojas))
print('Imagenes de 4 hojas: '+ str(imag_4_hojas))
print('Imagenes de 5 hojas: '+ str(imag_5_hojas))
print('Imagenes de 6 hojas: '+ str(imag_6_hojas))
print('Imagenes de 7 hojas: '+ str(imag_7_hojas))
print('Total: ', imag_1_hoja+imag_2_hojas+imag_3_hojas+imag_4_hojas+imag_5_hojas+imag_6_hojas+imag_7_hojas)
# Out:
# Imagenes de 1 hoja: 473
# Imagenes de 2 hojas: 466
# Imagenes de 3 hojas: 466
# Imagenes de 4 hojas: 501
# Imagenes de 5 hojas: 97
# Imagenes de 6 hojas: 58
# Imagenes de 7 hojas: 93
# Total:  2154

# %%
#Cuenta cuantas imágenes servirán para train, para validation y para test, en este caso se ha seguido el criterio 80%-10%-10% respectivamente.

n_imag_train_1 = round(imag_1_hoja*0.8)
n_imag_validation_1 = imag_1_hoja//10
n_imag_test_1 = imag_1_hoja-n_imag_train_1-n_imag_validation_1
print('1 hoja: Train=' + str(n_imag_train_1) + ' Validation=' + str(n_imag_validation_1) + ' Test=' + str(n_imag_test_1))
n_imag_train_2 = round(imag_2_hojas*0.8)
n_imag_validation_2 = imag_2_hojas//10
n_imag_test_2 = imag_2_hojas-n_imag_train_2-n_imag_validation_2
print('2 hojas: Train=' + str(n_imag_train_2) + ' Validation=' + str(n_imag_validation_2) + ' Test=' + str(n_imag_test_2))
n_imag_train_3 = round(imag_3_hojas*0.8)
n_imag_validation_3 = imag_3_hojas//10
n_imag_test_3 = imag_3_hojas-n_imag_train_3-n_imag_validation_3
print('3 hojas: Train=' + str(n_imag_train_3) + ' Validation=' + str(n_imag_validation_3) + ' Test=' + str(n_imag_test_3))
n_imag_train_4 = round(imag_4_hojas*0.8)
n_imag_validation_4 = imag_4_hojas//10
n_imag_test_4 = imag_4_hojas-n_imag_train_4-n_imag_validation_4
print('4 hojas: Train=' + str(n_imag_train_4) + ' Validation=' + str(n_imag_validation_4) + ' Test=' + str(n_imag_test_4))
n_imag_train_5 = round(imag_5_hojas*0.8)
n_imag_validation_5 = imag_5_hojas//10
n_imag_test_5 = imag_5_hojas-n_imag_train_5-n_imag_validation_5
print('5 hojas: Train=' + str(n_imag_train_5) + ' Validation=' + str(n_imag_validation_5) + ' Test=' + str(n_imag_test_5))
n_imag_train_6 = round(imag_6_hojas*0.8)
n_imag_validation_6 = imag_6_hojas//10
n_imag_test_6 = imag_6_hojas-n_imag_train_6-n_imag_validation_6
print('6 hojas: Train=' + str(n_imag_train_6) + ' Validation=' + str(n_imag_validation_6) + ' Test=' + str(n_imag_test_6))
n_imag_train_7 = round(imag_7_hojas*0.8)
n_imag_validation_7 = imag_7_hojas//10
n_imag_test_7 = imag_7_hojas-n_imag_train_7-n_imag_validation_7
print('7 hojas: Train=' + str(n_imag_train_7) + ' Validation=' + str(n_imag_validation_7) + ' Test=' + str(n_imag_test_7))
# Out:
# 1 hoja: Train=378 Validation=47 Test=48
# 2 hojas: Train=373 Validation=46 Test=47
# 3 hojas: Train=373 Validation=46 Test=47
# 4 hojas: Train=401 Validation=50 Test=50
# 5 hojas: Train=78 Validation=9 Test=10
# 6 hojas: Train=46 Validation=5 Test=7
# 7 hojas: Train=74 Validation=9 Test=10

# %%
#Asignamos cada ruta a variables que luego serán necesarias.

base_dir = "C:/Users/ferga/Documents/Python/hojas"

train_dir =      os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir =       os.path.join(base_dir, 'test')

## Directorio con las imagenes de train
# 1 hoja.
train_weed1_dir = os.path.join(train_dir, '1')
# 2 hojas.
train_weed2_dir = os.path.join(train_dir, '2')
# 3 hojas.
train_weed3_dir = os.path.join(train_dir, '3')
# 4 hojas.
train_weed4_dir = os.path.join(train_dir, '4')
# 5 hojas.
train_weed5_dir = os.path.join(train_dir, '5')
# 6 hojas.
train_weed6_dir = os.path.join(train_dir, '6')
# 7 hojas.
train_weed7_dir = os.path.join(train_dir, '7')

## Directorio con las imagenes de validation
# 1 hoja
validation_weed1_dir = os.path.join(validation_dir, '1')
# 2 hojas
validation_weed2_dir = os.path.join(validation_dir, '2')
# 3 hojas
validation_weed3_dir = os.path.join(validation_dir, '3')
# 4 hojas
validation_weed4_dir = os.path.join(validation_dir, '4')
# 5 hojas
validation_weed5_dir = os.path.join(validation_dir, '5')
# 6 hojas
validation_weed6_dir = os.path.join(validation_dir, '6')
# 7 hojas
validation_weed7_dir = os.path.join(validation_dir, '7')

## Directorio con las imagenes de test
# 1 hoja
test_weed1_dir = os.path.join(test_dir,'1')
# 2 hojas
test_weed2_dir = os.path.join(test_dir,'2')
# 3 hojas
test_weed3_dir = os.path.join(test_dir,'3')
# 4 hojas
test_weed4_dir = os.path.join(test_dir,'4')
# 5 hojas
test_weed5_dir = os.path.join(test_dir,'5')
# 6 hojas
test_weed6_dir = os.path.join(test_dir,'6')
# 7 hojas
test_weed7_dir = os.path.join(test_dir,'7')

# %%
# Ordena las imágenes de cada categoría en el directorio de train, validation y test.

# 1 hoja
contenido_1 = os.listdir(dir1)
contenido_1_random = sample(contenido_1, len(contenido_1))
for i in range(len(contenido_1_random)):
    if i < n_imag_train_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), train_weed1_dir)
    elif i >= n_imag_train_1 and i < n_imag_train_1+n_imag_validation_1:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), validation_weed1_dir)
    else:
        shutil.copy(os.path.join(dir1, contenido_1_random[i]), test_weed1_dir)
# 2 hojas
contenido_2 = os.listdir(dir2)
contenido_2_random = sample(contenido_2, len(contenido_2))
for i in range(len(contenido_2_random)):
    if i < n_imag_train_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), train_weed2_dir)
    elif i >= n_imag_train_2 and i < n_imag_train_2+n_imag_validation_2:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), validation_weed2_dir)
    else:
        shutil.copy(os.path.join(dir2, contenido_2_random[i]), test_weed2_dir)
# 3 hojas
contenido_3 = os.listdir(dir3)
contenido_3_random = sample(contenido_3, len(contenido_3))
for i in range(len(contenido_3_random)):
    if i < n_imag_train_3:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), train_weed3_dir)
    elif i >= n_imag_train_3 and i < n_imag_train_3+n_imag_validation_3:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), validation_weed3_dir)
    else:
        shutil.copy(os.path.join(dir3, contenido_3_random[i]), test_weed3_dir)
# 4 hojas
contenido_4 = os.listdir(dir4)
contenido_4_random = sample(contenido_4, len(contenido_4))
for i in range(len(contenido_4_random)):
    if i < n_imag_train_4:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), train_weed4_dir)
    elif i >= n_imag_train_4 and i < n_imag_train_4+n_imag_validation_4:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), validation_weed4_dir)
    else:
        shutil.copy(os.path.join(dir4, contenido_4_random[i]), test_weed4_dir)
# 5 hojas
contenido_5 = os.listdir(dir5)
contenido_5_random = sample(contenido_5, len(contenido_5))
for i in range(len(contenido_5_random)):
    if i < n_imag_train_5:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), train_weed5_dir)
    elif i >= n_imag_train_5 and i < n_imag_train_5+n_imag_validation_5:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), validation_weed5_dir)
    else:
        shutil.copy(os.path.join(dir5, contenido_5_random[i]), test_weed5_dir)
# 6 hojas
contenido_6 = os.listdir(dir6)
contenido_6_random = sample(contenido_6, len(contenido_6))
for i in range(len(contenido_6_random)):
    if i < n_imag_train_6:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), train_weed6_dir)
    elif i >= n_imag_train_6 and i < n_imag_train_6+n_imag_validation_6:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), validation_weed6_dir)
    else:
        shutil.copy(os.path.join(dir6, contenido_6_random[i]), test_weed6_dir)
# 7 hojas
contenido_7 = os.listdir(dir7)
contenido_7_random = sample(contenido_7, len(contenido_7))
for i in range(len(contenido_7_random)):
    if i < n_imag_train_7:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), train_weed7_dir)
    elif i >= n_imag_train_7 and i < n_imag_train_7+n_imag_validation_7:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), validation_weed7_dir)
    else:
        shutil.copy(os.path.join(dir7, contenido_7_random[i]), test_weed7_dir)

# %%
# Pequeña comprobación de que las fotos están bien ordenadas

# Train
train_weed1_fnames = os.listdir( train_weed1_dir )
print(train_weed1_fnames[:5])
train_weed2_fnames = os.listdir( train_weed2_dir )
print(train_weed2_fnames[:5])
train_weed3_fnames = os.listdir( train_weed3_dir )
print(train_weed3_fnames[:5])
train_weed4_fnames = os.listdir( train_weed4_dir )
print(train_weed4_fnames[:5])
train_weed5_fnames = os.listdir( train_weed5_dir )
print(train_weed5_fnames[:5])
train_weed6_fnames = os.listdir( train_weed6_dir )
print(train_weed6_fnames[:5])
train_weed7_fnames = os.listdir( train_weed7_dir )
print(train_weed7_fnames[:5])
# Out:
# ['1.png', '10.png', '100.png', '102.png', '106.png']
# ['1.png', '102.png', '103.png', '105.png', '11.png']
# ['1.png', '10.png', '104.png', '105.png', '107.png']
# ['1006.png', '1009.png', '1014.png', '102.png', '1023.png']
# ['104.png', '112.png', '113.png', '118.png', '127.png']
# ['102.png', '117.png', '120.png', '138.png', '149.png']
# ['0.png', '100.png', '101.png', '102.png', '103.png']

# %%
#Comprueba el numero de fotos que hay en cada directorio para verificar que se ha realizado el reparto correctamente

print('total training weed1 images :', len(os.listdir(train_weed1_dir ) ))
print('total training weed2 images :', len(os.listdir(train_weed2_dir ) ))
print('total training weed3 images :', len(os.listdir(train_weed3_dir ) ))
print('total training weed4 images :', len(os.listdir(train_weed4_dir ) ))
print('total training weed5 images :', len(os.listdir(train_weed5_dir ) ))
print('total training weed6 images :', len(os.listdir(train_weed6_dir ) ))
print('total training weed7 images :', len(os.listdir(train_weed7_dir ) ))

print('total validation weed1 images :', len(os.listdir( validation_weed1_dir ) ))
print('total validation weed2 images :', len(os.listdir( validation_weed2_dir ) ))
print('total validation weed3 images :', len(os.listdir( validation_weed3_dir ) ))
print('total validation weed4 images :', len(os.listdir( validation_weed4_dir ) ))
print('total validation weed5 images :', len(os.listdir( validation_weed5_dir ) ))
print('total validation weed6 images :', len(os.listdir( validation_weed6_dir ) ))
print('total validation weed7 images :', len(os.listdir( validation_weed7_dir ) ))

print('total test weed1 images :', len(os.listdir( test_weed1_dir ) ))
print('total test weed2 images :', len(os.listdir( test_weed2_dir ) ))
print('total test weed3 images :', len(os.listdir( test_weed3_dir ) ))
print('total test weed4 images :', len(os.listdir( test_weed4_dir ) ))
print('total test weed5 images :', len(os.listdir( test_weed5_dir ) ))
print('total test weed6 images :', len(os.listdir( test_weed6_dir ) ))
print('total test weed7 images :', len(os.listdir( test_weed7_dir ) ))
# Out:
# total training weed1 images : 378
# total training weed2 images : 373
# total training weed3 images : 373
# total training weed4 images : 401
# total training weed5 images : 78
# total training weed6 images : 46
# total training weed7 images : 74
# total validation weed1 images : 47
# total validation weed2 images : 46
# total validation weed3 images : 46
# total validation weed4 images : 50
# total validation weed5 images : 9
# total validation weed6 images : 5
# total validation weed7 images : 9
# total test weed1 images : 48
# total test weed2 images : 47
# total test weed3 images : 47
# total test weed4 images : 50
# total test weed5 images : 10
# total test weed6 images : 7
# total test weed7 images : 10

# %%
# Representa un ejemplo de las imágenes que se van a tomar para resolver el problema. En este caso se representarán las de dos hojas

# presentaremos images en una configuración de 4x4
nrows = 4
ncols = 4

pic_index = 0 # Índice para iterar sobre las imagenes

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index+=8

next_weed_pix = [os.path.join(train_weed2_dir, fname) 
                for fname in train_weed2_fnames[ pic_index-8:pic_index] 
               ]

for i, img_path in enumerate(next_weed_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  img = mpimg.imread(img_path)
  plt.imshow(img)
  
plt.show()

# %%
#Creación de la CNN

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu', ),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 256)         590080
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 1,242,695
# Trainable params: 1,242,695
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
      rescale=1.0/255.,
      rotation_range=60,
      horizontal_flip=True,
      vertical_flip=True,
      brightness_range=[0.5,1.5],
      fill_mode='nearest'
      )
validation_datagen  = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))     

validation_generator =  validation_datagen.flow_from_directory(validation_dir,
                                                         batch_size=20,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))


test_generator =  test_datagen.flow_from_directory(test_dir,
                                                         batch_size=20,
                                                         shuffle=False,
                                                         class_mode  = 'categorical',
                                                         target_size = (150, 150))
# Out:
# Found 1723 images belonging to 7 classes.
# Found 212 images belonging to 7 classes.
# Found 219 images belonging to 7 classes.

# %%
batch_size = 20
steps_per_epoch = train_generator.n // batch_size
validation_steps = validation_generator.n // batch_size

print (steps_per_epoch)
print (validation_steps)
# Out:
# 86
# 10

# %%
history = model.fit(
    train_generator, 
    steps_per_epoch= steps_per_epoch,
    epochs=150,
    validation_data=validation_generator,
    validation_steps= validation_steps,
    verbose=1)
# Out:
# Epoch 1/150
# 86/86 [==============================] - 18s 179ms/step - loss: 1.7836 - accuracy: 0.2361 - val_loss: 1.6610 - val_accuracy: 0.4000
# Epoch 2/150
# 86/86 [==============================] - 11s 130ms/step - loss: 1.6610 - accuracy: 0.3670 - val_loss: 1.5744 - val_accuracy: 0.4600
# Epoch 3/150
# 86/86 [==============================] - 11s 133ms/step - loss: 1.5715 - accuracy: 0.3964 - val_loss: 1.4883 - val_accuracy: 0.4400
# Epoch 4/150
# 86/86 [==============================] - 12s 135ms/step - loss: 1.5002 - accuracy: 0.4163 - val_loss: 1.4417 - val_accuracy: 0.3650
# Epoch 5/150
# 86/86 [==============================] - 12s 143ms/step - loss: 1.4470 - accuracy: 0.4339 - val_loss: 1.3155 - val_accuracy: 0.5050
# Epoch 6/150
# 86/86 [==============================] - 13s 153ms/step - loss: 1.3950 - accuracy: 0.4774 - val_loss: 1.3561 - val_accuracy: 0.4650
# Epoch 7/150
# 86/86 [==============================] - 12s 143ms/step - loss: 1.3649 - accuracy: 0.4739 - val_loss: 1.3310 - val_accuracy: 0.5050
# Epoch 8/150
# 86/86 [==============================] - 12s 140ms/step - loss: 1.3364 - accuracy: 0.4868 - val_loss: 1.3337 - val_accuracy: 0.5100
# Epoch 9/150
# 86/86 [==============================] - 12s 137ms/step - loss: 1.3034 - accuracy: 0.4891 - val_loss: 1.2357 - val_accuracy: 0.5850
# Epoch 10/150
# 86/86 [==============================] - 12s 137ms/step - loss: 1.2746 - accuracy: 0.5073 - val_loss: 1.1968 - val_accuracy: 0.5550
# Epoch 11/150
# 86/86 [==============================] - 12s 135ms/step - loss: 1.2342 - accuracy: 0.5332 - val_loss: 1.1708 - val_accuracy: 0.5850
# Epoch 12/150
# 86/86 [==============================] - 12s 139ms/step - loss: 1.2069 - accuracy: 0.5390 - val_loss: 1.1203 - val_accuracy: 0.6000
# Epoch 13/150
# 86/86 [==============================] - 12s 139ms/step - loss: 1.1833 - accuracy: 0.5414 - val_loss: 1.0784 - val_accuracy: 0.5850
# Epoch 14/150
# 86/86 [==============================] - 12s 135ms/step - loss: 1.1508 - accuracy: 0.5596 - val_loss: 1.0795 - val_accuracy: 0.6100
# Epoch 15/150
# 86/86 [==============================] - 12s 139ms/step - loss: 1.1493 - accuracy: 0.5619 - val_loss: 1.0811 - val_accuracy: 0.5450
# Epoch 16/150
# 86/86 [==============================] - 12s 136ms/step - loss: 1.0895 - accuracy: 0.5755 - val_loss: 1.0056 - val_accuracy: 0.6550
# Epoch 17/150
# 86/86 [==============================] - 12s 139ms/step - loss: 1.1026 - accuracy: 0.5713 - val_loss: 1.0289 - val_accuracy: 0.6350
# Epoch 18/150
# 86/86 [==============================] - 13s 150ms/step - loss: 1.0824 - accuracy: 0.5895 - val_loss: 0.9628 - val_accuracy: 0.6500
# Epoch 19/150
# 86/86 [==============================] - 12s 140ms/step - loss: 1.1024 - accuracy: 0.5972 - val_loss: 0.9949 - val_accuracy: 0.6150
# Epoch 20/150
# 86/86 [==============================] - 11s 130ms/step - loss: 1.0302 - accuracy: 0.5960 - val_loss: 1.3209 - val_accuracy: 0.5150
# Epoch 21/150
# 86/86 [==============================] - 12s 134ms/step - loss: 1.0754 - accuracy: 0.6048 - val_loss: 0.9671 - val_accuracy: 0.6800
# Epoch 22/150
# 86/86 [==============================] - 12s 136ms/step - loss: 1.0348 - accuracy: 0.6113 - val_loss: 0.9574 - val_accuracy: 0.6300
# Epoch 23/150
# 86/86 [==============================] - 11s 132ms/step - loss: 1.0158 - accuracy: 0.6142 - val_loss: 0.9655 - val_accuracy: 0.6400
# Epoch 24/150
# 86/86 [==============================] - 12s 133ms/step - loss: 0.9865 - accuracy: 0.6324 - val_loss: 0.9429 - val_accuracy: 0.6350
# Epoch 25/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.9989 - accuracy: 0.6201 - val_loss: 0.9035 - val_accuracy: 0.6950
# Epoch 26/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.9662 - accuracy: 0.6277 - val_loss: 0.9533 - val_accuracy: 0.6700
# Epoch 27/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.9610 - accuracy: 0.6365 - val_loss: 0.9379 - val_accuracy: 0.6700
# Epoch 28/150
# 86/86 [==============================] - 12s 145ms/step - loss: 0.9683 - accuracy: 0.6301 - val_loss: 0.8899 - val_accuracy: 0.6800
# Epoch 29/150
# 86/86 [==============================] - 13s 145ms/step - loss: 0.9503 - accuracy: 0.6447 - val_loss: 0.8777 - val_accuracy: 0.6400
# Epoch 30/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.9350 - accuracy: 0.6430 - val_loss: 0.8974 - val_accuracy: 0.6950
# Epoch 31/150
# 86/86 [==============================] - 12s 135ms/step - loss: 0.9213 - accuracy: 0.6483 - val_loss: 0.8645 - val_accuracy: 0.7050
# Epoch 32/150
# 86/86 [==============================] - 14s 161ms/step - loss: 0.8973 - accuracy: 0.6741 - val_loss: 0.8988 - val_accuracy: 0.6500
# Epoch 33/150
# 86/86 [==============================] - 12s 137ms/step - loss: 0.9162 - accuracy: 0.6518 - val_loss: 0.8909 - val_accuracy: 0.6450
# Epoch 34/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.8860 - accuracy: 0.6618 - val_loss: 0.8213 - val_accuracy: 0.6850
# Epoch 35/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.8756 - accuracy: 0.6747 - val_loss: 0.8920 - val_accuracy: 0.7100
# Epoch 36/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.8796 - accuracy: 0.6618 - val_loss: 0.9384 - val_accuracy: 0.6200
# Epoch 37/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.8966 - accuracy: 0.6712 - val_loss: 0.8103 - val_accuracy: 0.7250
# Epoch 38/150
# 86/86 [==============================] - 13s 151ms/step - loss: 0.8635 - accuracy: 0.6794 - val_loss: 0.8767 - val_accuracy: 0.6900
# Epoch 39/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.8761 - accuracy: 0.6723 - val_loss: 0.8381 - val_accuracy: 0.6950
# Epoch 40/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.8808 - accuracy: 0.6765 - val_loss: 0.8348 - val_accuracy: 0.6900
# Epoch 41/150
# 86/86 [==============================] - 13s 152ms/step - loss: 0.8291 - accuracy: 0.6929 - val_loss: 0.8753 - val_accuracy: 0.6900
# Epoch 42/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.8456 - accuracy: 0.6853 - val_loss: 0.8582 - val_accuracy: 0.6750
# Epoch 43/150
# 86/86 [==============================] - 12s 133ms/step - loss: 0.8760 - accuracy: 0.6835 - val_loss: 0.8860 - val_accuracy: 0.6750
# Epoch 44/150
# 86/86 [==============================] - 11s 126ms/step - loss: 0.8229 - accuracy: 0.6941 - val_loss: 0.8635 - val_accuracy: 0.6800
# Epoch 45/150
# 86/86 [==============================] - 11s 129ms/step - loss: 0.8246 - accuracy: 0.6923 - val_loss: 0.8241 - val_accuracy: 0.7150
# Epoch 46/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.8356 - accuracy: 0.6882 - val_loss: 0.8254 - val_accuracy: 0.7300
# Epoch 47/150
# 86/86 [==============================] - 11s 129ms/step - loss: 0.8418 - accuracy: 0.6876 - val_loss: 0.7859 - val_accuracy: 0.7400
# Epoch 48/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.8215 - accuracy: 0.7052 - val_loss: 0.7671 - val_accuracy: 0.7550
# Epoch 49/150
# 86/86 [==============================] - 12s 143ms/step - loss: 0.8187 - accuracy: 0.6970 - val_loss: 0.8038 - val_accuracy: 0.6850
# Epoch 50/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.8174 - accuracy: 0.7005 - val_loss: 0.7473 - val_accuracy: 0.7500
# Epoch 51/150
# 86/86 [==============================] - 12s 137ms/step - loss: 0.8171 - accuracy: 0.6911 - val_loss: 0.7731 - val_accuracy: 0.7300
# Epoch 52/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.8031 - accuracy: 0.7011 - val_loss: 0.7803 - val_accuracy: 0.7100
# Epoch 53/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.7776 - accuracy: 0.7293 - val_loss: 0.7567 - val_accuracy: 0.7000
# Epoch 54/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.7983 - accuracy: 0.7099 - val_loss: 0.7645 - val_accuracy: 0.7300
# Epoch 55/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.7993 - accuracy: 0.7146 - val_loss: 0.7822 - val_accuracy: 0.7100
# Epoch 56/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.7926 - accuracy: 0.7011 - val_loss: 0.7732 - val_accuracy: 0.7200
# Epoch 57/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.7907 - accuracy: 0.7105 - val_loss: 0.7352 - val_accuracy: 0.7650
# Epoch 58/150
# 86/86 [==============================] - 12s 145ms/step - loss: 0.7802 - accuracy: 0.7158 - val_loss: 0.7830 - val_accuracy: 0.7200
# Epoch 59/150
# 86/86 [==============================] - 14s 157ms/step - loss: 0.7815 - accuracy: 0.7052 - val_loss: 0.8104 - val_accuracy: 0.7050
# Epoch 60/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.7602 - accuracy: 0.7240 - val_loss: 0.8164 - val_accuracy: 0.6900
# Epoch 61/150
# 86/86 [==============================] - 13s 149ms/step - loss: 0.7713 - accuracy: 0.7234 - val_loss: 0.7510 - val_accuracy: 0.7100
# Epoch 62/150
# 86/86 [==============================] - 12s 136ms/step - loss: 0.7608 - accuracy: 0.7305 - val_loss: 0.8062 - val_accuracy: 0.6850
# Epoch 63/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.7426 - accuracy: 0.7346 - val_loss: 0.7114 - val_accuracy: 0.7350
# Epoch 64/150
# 86/86 [==============================] - 12s 136ms/step - loss: 0.7448 - accuracy: 0.7246 - val_loss: 0.8845 - val_accuracy: 0.6600
# Epoch 65/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.7572 - accuracy: 0.7170 - val_loss: 0.6878 - val_accuracy: 0.7550
# Epoch 66/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.7369 - accuracy: 0.7217 - val_loss: 0.7490 - val_accuracy: 0.7150
# Epoch 67/150
# 86/86 [==============================] - 12s 139ms/step - loss: 0.7317 - accuracy: 0.7387 - val_loss: 0.7390 - val_accuracy: 0.7450
# Epoch 68/150
# 86/86 [==============================] - 12s 137ms/step - loss: 0.7206 - accuracy: 0.7424 - val_loss: 0.7461 - val_accuracy: 0.7350
# Epoch 69/150
# 86/86 [==============================] - 12s 143ms/step - loss: 0.7383 - accuracy: 0.7234 - val_loss: 0.7207 - val_accuracy: 0.7700
# Epoch 70/150
# 86/86 [==============================] - 12s 139ms/step - loss: 0.7308 - accuracy: 0.7340 - val_loss: 0.7220 - val_accuracy: 0.7300
# Epoch 71/150
# 86/86 [==============================] - 12s 136ms/step - loss: 0.7123 - accuracy: 0.7299 - val_loss: 0.7066 - val_accuracy: 0.7500
# Epoch 72/150
# 86/86 [==============================] - 13s 145ms/step - loss: 0.7174 - accuracy: 0.7358 - val_loss: 0.7159 - val_accuracy: 0.7400
# Epoch 73/150
# 86/86 [==============================] - 14s 159ms/step - loss: 0.7286 - accuracy: 0.7363 - val_loss: 0.7145 - val_accuracy: 0.7300
# Epoch 74/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.7070 - accuracy: 0.7422 - val_loss: 0.9238 - val_accuracy: 0.6550
# Epoch 75/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.7181 - accuracy: 0.7413 - val_loss: 0.6910 - val_accuracy: 0.7500
# Epoch 76/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.7126 - accuracy: 0.7322 - val_loss: 0.7056 - val_accuracy: 0.7300
# Epoch 77/150
# 86/86 [==============================] - 12s 138ms/step - loss: 0.6936 - accuracy: 0.7528 - val_loss: 0.7413 - val_accuracy: 0.7300
# Epoch 78/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.7183 - accuracy: 0.7452 - val_loss: 0.7737 - val_accuracy: 0.7300
# Epoch 79/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.7043 - accuracy: 0.7375 - val_loss: 0.7662 - val_accuracy: 0.7450
# Epoch 80/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.7132 - accuracy: 0.7352 - val_loss: 0.6797 - val_accuracy: 0.7500
# Epoch 81/150
# 86/86 [==============================] - 12s 143ms/step - loss: 0.7155 - accuracy: 0.7293 - val_loss: 0.7327 - val_accuracy: 0.7300
# Epoch 82/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.7010 - accuracy: 0.7428 - val_loss: 0.7065 - val_accuracy: 0.7400
# Epoch 83/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.6826 - accuracy: 0.7616 - val_loss: 0.7291 - val_accuracy: 0.7250
# Epoch 84/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.7240 - accuracy: 0.7416 - val_loss: 0.7034 - val_accuracy: 0.7600
# Epoch 85/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.6811 - accuracy: 0.7563 - val_loss: 0.6819 - val_accuracy: 0.7650
# Epoch 86/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.6652 - accuracy: 0.7516 - val_loss: 0.7330 - val_accuracy: 0.7150
# Epoch 87/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.6560 - accuracy: 0.7628 - val_loss: 0.7502 - val_accuracy: 0.7200
# Epoch 88/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.6580 - accuracy: 0.7481 - val_loss: 0.7081 - val_accuracy: 0.7350
# Epoch 89/150
# 86/86 [==============================] - 13s 149ms/step - loss: 0.6645 - accuracy: 0.7663 - val_loss: 0.7033 - val_accuracy: 0.7200
# Epoch 90/150
# 86/86 [==============================] - 12s 138ms/step - loss: 0.6709 - accuracy: 0.7610 - val_loss: 0.7566 - val_accuracy: 0.7450
# Epoch 91/150
# 86/86 [==============================] - 12s 138ms/step - loss: 0.6563 - accuracy: 0.7592 - val_loss: 0.7125 - val_accuracy: 0.7600
# Epoch 92/150
# 86/86 [==============================] - 12s 136ms/step - loss: 0.6761 - accuracy: 0.7510 - val_loss: 0.7374 - val_accuracy: 0.7400
# Epoch 93/150
# 86/86 [==============================] - 12s 143ms/step - loss: 0.6453 - accuracy: 0.7604 - val_loss: 0.7783 - val_accuracy: 0.7400
# Epoch 94/150
# 86/86 [==============================] - 13s 150ms/step - loss: 0.6452 - accuracy: 0.7546 - val_loss: 0.7276 - val_accuracy: 0.7650
# Epoch 95/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.6547 - accuracy: 0.7604 - val_loss: 0.7571 - val_accuracy: 0.7400
# Epoch 96/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.6699 - accuracy: 0.7405 - val_loss: 0.7298 - val_accuracy: 0.7600
# Epoch 97/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.6310 - accuracy: 0.7739 - val_loss: 0.6969 - val_accuracy: 0.7400
# Epoch 98/150
# 86/86 [==============================] - 11s 127ms/step - loss: 0.6352 - accuracy: 0.7669 - val_loss: 0.7838 - val_accuracy: 0.7200
# Epoch 99/150
# 86/86 [==============================] - 11s 129ms/step - loss: 0.6467 - accuracy: 0.7563 - val_loss: 0.7657 - val_accuracy: 0.7200
# Epoch 100/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.6396 - accuracy: 0.7751 - val_loss: 0.7644 - val_accuracy: 0.7000
# Epoch 101/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.6378 - accuracy: 0.7692 - val_loss: 0.7784 - val_accuracy: 0.7200
# Epoch 102/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.6344 - accuracy: 0.7728 - val_loss: 0.7288 - val_accuracy: 0.7450
# Epoch 103/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.6505 - accuracy: 0.7522 - val_loss: 0.7639 - val_accuracy: 0.7350
# Epoch 104/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.6297 - accuracy: 0.7692 - val_loss: 0.7271 - val_accuracy: 0.7400
# Epoch 105/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.6264 - accuracy: 0.7639 - val_loss: 0.8412 - val_accuracy: 0.7100
# Epoch 106/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.6269 - accuracy: 0.7681 - val_loss: 0.6993 - val_accuracy: 0.7600
# Epoch 107/150
# 86/86 [==============================] - 13s 145ms/step - loss: 0.6153 - accuracy: 0.7821 - val_loss: 0.7455 - val_accuracy: 0.7300
# Epoch 108/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.6257 - accuracy: 0.7657 - val_loss: 0.7163 - val_accuracy: 0.7500
# Epoch 109/150
# 86/86 [==============================] - 11s 132ms/step - loss: 0.6059 - accuracy: 0.7763 - val_loss: 0.7488 - val_accuracy: 0.7350
# Epoch 110/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.5885 - accuracy: 0.7839 - val_loss: 0.7051 - val_accuracy: 0.7450
# Epoch 111/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.6119 - accuracy: 0.7745 - val_loss: 0.6940 - val_accuracy: 0.7650
# Epoch 112/150
# 86/86 [==============================] - 11s 128ms/step - loss: 0.6162 - accuracy: 0.7798 - val_loss: 0.9213 - val_accuracy: 0.6800
# Epoch 113/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.6015 - accuracy: 0.7810 - val_loss: 0.6529 - val_accuracy: 0.7800
# Epoch 114/150
# 86/86 [==============================] - 11s 130ms/step - loss: 0.5834 - accuracy: 0.7886 - val_loss: 0.6950 - val_accuracy: 0.7500
# Epoch 115/150
# 86/86 [==============================] - 12s 133ms/step - loss: 0.5954 - accuracy: 0.7821 - val_loss: 0.7097 - val_accuracy: 0.7500
# Epoch 116/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.5934 - accuracy: 0.7763 - val_loss: 0.6808 - val_accuracy: 0.7550
# Epoch 117/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.6130 - accuracy: 0.7821 - val_loss: 0.6621 - val_accuracy: 0.7700
# Epoch 118/150
# 86/86 [==============================] - 13s 152ms/step - loss: 0.5765 - accuracy: 0.7780 - val_loss: 0.6562 - val_accuracy: 0.7300
# Epoch 119/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.5987 - accuracy: 0.7745 - val_loss: 0.6704 - val_accuracy: 0.7500
# Epoch 120/150
# 86/86 [==============================] - 11s 129ms/step - loss: 0.5828 - accuracy: 0.7892 - val_loss: 0.7339 - val_accuracy: 0.7050
# Epoch 121/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.5500 - accuracy: 0.7886 - val_loss: 0.7149 - val_accuracy: 0.7350
# Epoch 122/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.5660 - accuracy: 0.7921 - val_loss: 0.7287 - val_accuracy: 0.7400
# Epoch 123/150
# 86/86 [==============================] - 11s 131ms/step - loss: 0.5926 - accuracy: 0.7845 - val_loss: 0.6971 - val_accuracy: 0.7600
# Epoch 124/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.5752 - accuracy: 0.7878 - val_loss: 0.7058 - val_accuracy: 0.7450
# Epoch 125/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.5651 - accuracy: 0.7974 - val_loss: 0.6955 - val_accuracy: 0.7600
# Epoch 126/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.5860 - accuracy: 0.8056 - val_loss: 0.7263 - val_accuracy: 0.7400
# Epoch 127/150
# 86/86 [==============================] - 13s 145ms/step - loss: 0.5695 - accuracy: 0.7939 - val_loss: 0.7112 - val_accuracy: 0.7550
# Epoch 128/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.5450 - accuracy: 0.7992 - val_loss: 0.7445 - val_accuracy: 0.7400
# Epoch 129/150
# 86/86 [==============================] - 11s 128ms/step - loss: 0.5451 - accuracy: 0.8139 - val_loss: 0.7314 - val_accuracy: 0.7650
# Epoch 130/150
# 86/86 [==============================] - 11s 129ms/step - loss: 0.5815 - accuracy: 0.7827 - val_loss: 0.7588 - val_accuracy: 0.7250
# Epoch 131/150
# 86/86 [==============================] - 11s 133ms/step - loss: 0.5504 - accuracy: 0.8027 - val_loss: 0.7561 - val_accuracy: 0.7250
# Epoch 132/150
# 86/86 [==============================] - 12s 134ms/step - loss: 0.5544 - accuracy: 0.8062 - val_loss: 0.7290 - val_accuracy: 0.7800
# Epoch 133/150
# 86/86 [==============================] - 12s 135ms/step - loss: 0.5508 - accuracy: 0.7968 - val_loss: 0.6960 - val_accuracy: 0.7600
# Epoch 134/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.5410 - accuracy: 0.8009 - val_loss: 0.7173 - val_accuracy: 0.7550
# Epoch 135/150
# 86/86 [==============================] - 15s 176ms/step - loss: 0.5623 - accuracy: 0.7845 - val_loss: 0.6705 - val_accuracy: 0.7550
# Epoch 136/150
# 86/86 [==============================] - 12s 137ms/step - loss: 0.5254 - accuracy: 0.8045 - val_loss: 0.6873 - val_accuracy: 0.7550
# Epoch 137/150
# 86/86 [==============================] - 14s 162ms/step - loss: 0.5212 - accuracy: 0.8021 - val_loss: 0.8147 - val_accuracy: 0.6900
# Epoch 138/150
# 86/86 [==============================] - 14s 161ms/step - loss: 0.5498 - accuracy: 0.7874 - val_loss: 0.8089 - val_accuracy: 0.6850
# Epoch 139/150
# 86/86 [==============================] - 16s 186ms/step - loss: 0.5551 - accuracy: 0.7962 - val_loss: 0.7748 - val_accuracy: 0.7000
# Epoch 140/150
# 86/86 [==============================] - 14s 160ms/step - loss: 0.5443 - accuracy: 0.8050 - val_loss: 0.7177 - val_accuracy: 0.7350
# Epoch 141/150
# 86/86 [==============================] - 13s 146ms/step - loss: 0.5282 - accuracy: 0.7998 - val_loss: 0.7261 - val_accuracy: 0.7250
# Epoch 142/150
# 86/86 [==============================] - 13s 145ms/step - loss: 0.5386 - accuracy: 0.8127 - val_loss: 0.6731 - val_accuracy: 0.7300
# Epoch 143/150
# 86/86 [==============================] - 12s 142ms/step - loss: 0.5243 - accuracy: 0.8039 - val_loss: 0.6791 - val_accuracy: 0.7550
# Epoch 144/150
# 86/86 [==============================] - 12s 141ms/step - loss: 0.5308 - accuracy: 0.8039 - val_loss: 0.7134 - val_accuracy: 0.7400
# Epoch 145/150
# 86/86 [==============================] - 16s 184ms/step - loss: 0.5349 - accuracy: 0.7939 - val_loss: 0.8025 - val_accuracy: 0.6900loss: 0.5 - ETA: 3s - loss: 0.5 - ETA: 1s - loss: 0.531
# Epoch 146/150
# 86/86 [==============================] - 14s 166ms/step - loss: 0.5327 - accuracy: 0.8103 - val_loss: 0.7448 - val_accuracy: 0.6950
# Epoch 147/150
# 86/86 [==============================] - 12s 143ms/step - loss: 0.5195 - accuracy: 0.8115 - val_loss: 0.7718 - val_accuracy: 0.7250
# Epoch 148/150
# 86/86 [==============================] - 12s 142ms/step - loss: 0.5278 - accuracy: 0.8103 - val_loss: 0.6981 - val_accuracy: 0.7450
# Epoch 149/150
# 86/86 [==============================] - 12s 140ms/step - loss: 0.5190 - accuracy: 0.8174 - val_loss: 0.6742 - val_accuracy: 0.7650
# Epoch 150/150
# 86/86 [==============================] - 12s 139ms/step - loss: 0.4907 - accuracy: 0.8186 - val_loss: 0.7605 - val_accuracy: 0.7450

# %%
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs    = range(1,len(acc)+1,1) # obtener número de epochs del eje X

plt.plot  ( epochs,     acc, 'r--', label='Training acc'  )
plt.plot  ( epochs, val_acc,  'b', label='Validation acc')
plt.title ('Training and Validation Accuracy')
plt.ylabel('acc')
plt.xlabel('epochs')

plt.legend()
plt.figure()


plt.plot  ( epochs,     loss, 'r--' )
plt.plot  ( epochs, val_loss ,  'b' )
plt.title ('Training and Validation Loss'   )
plt.ylabel('loss')
plt.xlabel('epochs')

plt.legend()
plt.figure()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
test_lost, test_acc= model.evaluate(test_generator)
print ("Test Accuracy:", test_acc)
# Out:
# 11/11 [==============================] - 1s 106ms/step - loss: 0.7708 - accuracy: 0.7123
# Test Accuracy: 0.7123287916183472

# %%
# Guardar el modelo
model.save('CH_V_7hojas_cv.h5')

# %%
# Cargar modelo
model = tf.keras.models.load_model('CH_V_6hojas_cv.h5')

# %%
# Confusion matrix
Y_pred = model.predict(test_generator, len(test_dir) // (20+1))
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))
print('Classification Report')
target_names = ['1', '2', '3','4', '5','6','7']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[43  2  3  0  0  0  0]
#  [ 3 35  8  1  0  0  0]
#  [ 4  8 27  6  0  0  2]
#  [ 0  4  3 40  1  0  2]
#  [ 0  0  0  7  1  0  2]
#  [ 0  0  0  1  1  3  2]
#  [ 0  0  1  0  1  1  7]]
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.86      0.90      0.88        48
#            2       0.71      0.74      0.73        47
#            3       0.64      0.57      0.61        47
#            4       0.73      0.80      0.76        50
#            5       0.25      0.10      0.14        10
#            6       0.75      0.43      0.55         7
#            7       0.47      0.70      0.56        10
#
#     accuracy                           0.71       219
#    macro avg       0.63      0.61      0.60       219
# weighted avg       0.70      0.71      0.70       219
